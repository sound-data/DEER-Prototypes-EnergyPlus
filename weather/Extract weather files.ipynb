# %%
# Extract CZ01-CZ16 weather files from ZIP archives for specific year
# The ZIP archives can be downloaded from https://www.calmac.org/weather.asp

# For example, the input will be a ZIP archive like this:
# CZ2022_ALL_HIST.zip
# +---CA_EUREKA_725940_22.zip
# |   +---CA_EUREKA_725940_22.EPW
# |   +---...
# +---CA_NAPA-CO_724955_22.zip
# |   +---CA_NAPA-CO_724955_22.EPW
# |   +---...
# +---...

# The output will be a folder like this:
# weatherCY2022
# +---CZ01-CA_EUREKA_725940_CY2022.epw
# +---CZ02-CA_NAPA-CO_724955_CY2022.epw

# %%
from zipfile import ZipFile
from pathlib import Path
import re

# %%
import requests

# %%
from datetime import datetime

# %%
# Define URLs to get CALMAC weather data for CZ2022 and CZ2025
# Each ZIP file is a nested zip archive with nested zip files containing epw, FIN4, and BINM files
DEER2024_bundle_filename = Path('CZ2022_ALL.zip')
DEER2024_bundle_href = 'https://www.calmac.org/weather/CZ2022/CZ2022_ALL.zip'

CZ2025_bundle_filename = Path('CZ2025_ALL.zip')
CZ2025_bundle_href = 'https://www.calmac.org/weather/CZ2025/CZ2025_ALL.zip'

# %%
# Get all CZ2025 weather files if not already present in current folder
if not CZ2025_bundle_filename.exists():
    print("Downloading", CZ2025_bundle_href)
    r0=requests.head(CZ2025_bundle_href)
    print(r0.headers)
    r1 = requests.get(CZ2025_bundle_href)
    r1.raise_for_status()
    CZ2025_bundle_filename.write_bytes(r1.content)

filestats = CZ2025_bundle_filename.stat()
print(CZ2025_bundle_filename,
      filestats.st_size,
      datetime.fromtimestamp(filestats.st_mtime).isoformat())
# Out:
# CZ2025_ALL.zip 60952600 2026-02-27T13:42:20.777730

# %%
# Define input zip file as CZ2025 file
inputzip = CZ2025_bundle_filename

# %%
# Defining the exact file name of the station in each climate zone

# DEER 2024 mapping is based on weather files used in the initial release of DEER 2024
cec_cz_map_deer2024 = [
    ('CZ01', 'CA_EUREKA_725940'),
    ('CZ02', 'CA_NAPA-CO_724955'),
    ('CZ03', 'CA_OAKLAND-METRO-AP_724930'),
    ('CZ04', 'CA_SAN-JOSE-IAP_724945'),
    ('CZ05', 'CA_SANTA-MARIA-PUBLIC-AP_723940'),
    ('CZ06', 'CA_LOS-ANGELES-IAP_722950'),
    ('CZ07', 'CA_SAN-DIEGO-LINDBERGH-F.*_722900'),
    ('CZ08', 'CA_LONG-BEACH-DAUGHERTY-FLD_722970'),
    ('CZ09', 'CA_LOS-ANGELES-DOWNTOWN-USC_722874'),
    ('CZ10', 'CA_RIVERSIDE-MUNI_722869'),
    ('CZ11', 'CA_RED-BLUFF-MUNI-AP_725910'),
    ('CZ12', 'CA_STOCKTON-METRO-AP_724920'),
    ('CZ13', 'CA_FRESNO-YOSEMITE-IAP_723890'),
    ('CZ14', 'CA_DAGGETT-BARSTOW-.*_723815'),
    ('CZ15', 'CA_EL-CENTRO-NAF_722810'),
    ('CZ16', 'CA_BISHOP-AP_724800'),
]

# CZ2025 mapping is based on the Title 24 Energy Code Accounting Report (2024)
cec_cz_map_cz2025 = [
    ('CZ01', 'CA_ARCATA-AP_725945',725945),
    ('CZ02', 'CA_SANTA-ROSA(AWOS)_724957',724957),
    ('CZ03', 'CA_OAKLAND-METRO-AP_724930',724930),
    ('CZ04', 'CA_PASO-ROBLES-MUNI-AP_723965',723965),
    ('CZ05', 'CA_SANTA-MARIA-PUBLIC-AP_723940',723940),
    ('CZ06', 'CA_LOS-ANGELES-IAP_722950',722950),
    ('CZ07', 'CA_SAN-DIEGO-LINDBERGH-FIELD_722900',722900),
    ('CZ08', 'CA_FULLERTON-MUNI-AP_722976',722976),
    ('CZ09', 'CA_BURBANK-GLNDLE-PASAD-AP_722880',722880),
    ('CZ10', 'CA_RIVERSIDE-MUNI_722869',722869),
    ('CZ11', 'CA_RED-BLUFF-MUNI-AP_725910',725910),
    ('CZ12', 'CA_SACRAMENTO-EXECUTIVE-AP_724830',724830),
    ('CZ13', 'CA_FRESNO-YOSEMITE-IAP_723890',723890),
    ('CZ14', 'CA_PALMDALE-AP_723820',723820),
    ('CZ15', 'CA_PALM-SPRINGS-IAP_722868',722868),
    ('CZ16', 'CA_BLUE-CANYON-AP_725845',725845),
]

# %%
# Defining a function to get the list of all files in the nested zip archive
# Returns a list of tuples (zi1, zi2) where zi1 is the name of the zip file for a given station
# and zi2 is any file within that zip (epw, FIN4, or BINM)
def get_contents(inputzip: Path) -> list:
    contents=[]
    with ZipFile(inputzip) as zf1:
        for zi1 in zf1.infolist():
            print(zi1.filename)
            try:
                with ZipFile(zf1.open(zi1)) as zf2:
                    for zi2 in zf2.infolist():
                        print("+---",zi2.filename)
                        contents.append((zi1.filename,zi2.filename))
            except:
                pass
    return contents

# Defining a function to get the relevant epw files based on defined CZ map
# Returns a tuple (zi1, zi2) where zi1 is the name of the zip file for a given station
# and zi2 is the name of the epw file within that zip
def get_cz_file(station: str, contents: list) -> tuple:
        print("Searching for", station)
        for fnames in contents:
            # criteria 1. find the matching weather station.
            # criteria 2. Find the EPW file within.
            if (
                fnames[0].startswith(station)
                and fnames[-1].upper().endswith('EPW')
            ):
                print(fnames)
                return(fnames)
        raise RuntimeError(f"No EPW file found for station {station}")

# Defining a function to extract relevant epw files and save them in the output folder
# The output file name will be in the format of CZxx-CALMACstation.epw, where xx is the climate zone number and CALMACstation is the file name as saved on CALMAC
def extract_weather(cec_cz_map: list, contents: list, inputzip: Path, output_folder: Path):
    output_folder.mkdir(exist_ok=True)
    for (cz, station, station_id) in cec_cz_map:
        zi1, zi2 = get_cz_file(station, contents)
        output_file = output_folder / (cz + '-' + zi2)
        
        with ZipFile(inputzip) as zf1:
            with ZipFile(zf1.open(zi1)) as zf2:
                with zf2.open(zi2) as file_epw:
                    output_file.write_bytes(file_epw.read())
                    print(output_file)

# %%
# Define output folder and run the extraction function
output_folder = Path('CZ2025')
contents = get_contents(inputzip)
print()
extract_weather(cec_cz_map_cz2025, contents, inputzip, output_folder)
print('Done')
# Out:
# CA_ALTURAS_725958_CZ2025.zip
# +--- CA_ALTURAS_725958_CZ2025.BINM
# +--- CA_ALTURAS_725958_CZ2025.epw
# +--- CA_ALTURAS_725958_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_ARCATA-AP_725945_CZ2025.zip
# +--- CA_ARCATA-AP_725945_CZ2025.BINM
# +--- CA_ARCATA-AP_725945_CZ2025.epw
# +--- CA_ARCATA-AP_725945_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_AUBURN-MUNI-AP_720267_CZ2025.zip
# +--- CA_AUBURN-MUNI-AP_720267_CZ2025.BINM
# +--- CA_AUBURN-MUNI-AP_720267_CZ2025.epw
# +--- CA_AUBURN-MUNI-AP_720267_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BAKERSFIELD-MEADOWS-FLD_723840_CZ2025.zip
# +--- CA_BAKERSFIELD-MEADOWS-FLD_723840_CZ2025.BINM
# +--- CA_BAKERSFIELD-MEADOWS-FLD_723840_CZ2025.epw
# +--- CA_BAKERSFIELD-MEADOWS-FLD_723840_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BEALE-AFB_724837_CZ2025.zip
# +--- CA_BEALE-AFB_724837_CZ2025.BINM
# +--- CA_BEALE-AFB_724837_CZ2025.epw
# +--- CA_BEALE-AFB_724837_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BICYCLE-LAKE-FORT-IRWIN-AAF_746110_CZ2025.zip
# +--- CA_BICYCLE-LAKE-FORT-IRWIN-AAF_746110_CZ2025.BINM
# +--- CA_BICYCLE-LAKE-FORT-IRWIN-AAF_746110_CZ2025.epw
# +--- CA_BICYCLE-LAKE-FORT-IRWIN-AAF_746110_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BIG-BEAR-CITY_720165_CZ2025.zip
# +--- CA_BIG-BEAR-CITY_720165_CZ2025.BINM
# +--- CA_BIG-BEAR-CITY_720165_CZ2025.epw
# +--- CA_BIG-BEAR-CITY_720165_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BISHOP-AP_724800_CZ2025.zip
# +--- CA_BISHOP-AP_724800_CZ2025.BINM
# +--- CA_BISHOP-AP_724800_CZ2025.epw
# +--- CA_BISHOP-AP_724800_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BLUE-CANYON-AP_725845_CZ2025.zip
# +--- CA_BLUE-CANYON-AP_725845_CZ2025.BINM
# +--- CA_BLUE-CANYON-AP_725845_CZ2025.epw
# +--- CA_BLUE-CANYON-AP_725845_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BLYTHE-RIVERSIDE-CO-AP_747188_CZ2025.zip
# +--- CA_BLYTHE-RIVERSIDE-CO-AP_747188_CZ2025.BINM
# +--- CA_BLYTHE-RIVERSIDE-CO-AP_747188_CZ2025.epw
# +--- CA_BLYTHE-RIVERSIDE-CO-AP_747188_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BROWN-FLD-MUNI_722904_CZ2025.zip
# +--- CA_BROWN-FLD-MUNI_722904_CZ2025.BINM
# +--- CA_BROWN-FLD-MUNI_722904_CZ2025.epw
# +--- CA_BROWN-FLD-MUNI_722904_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.zip
# +--- CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.BINM
# +--- CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.epw
# +--- CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CALAVERAS-CO-MAURY-RASMUSSEN_720681_CZ2025.zip
# +--- CA_CALAVERAS-CO-MAURY-RASMUSSEN_720681_CZ2025.BINM
# +--- CA_CALAVERAS-CO-MAURY-RASMUSSEN_720681_CZ2025.epw
# +--- CA_CALAVERAS-CO-MAURY-RASMUSSEN_720681_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CAMARILLO-AP_723926_CZ2025.zip
# +--- CA_CAMARILLO-AP_723926_CZ2025.BINM
# +--- CA_CAMARILLO-AP_723926_CZ2025.epw
# +--- CA_CAMARILLO-AP_723926_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CAMP-PENDLETON-MCAS_722926_CZ2025.zip
# +--- CA_CAMP-PENDLETON-MCAS_722926_CZ2025.BINM
# +--- CA_CAMP-PENDLETON-MCAS_722926_CZ2025.epw
# +--- CA_CAMP-PENDLETON-MCAS_722926_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CAMP-PENDLETON-RED-BEACH_722928_CZ2025.zip
# +--- CA_CAMP-PENDLETON-RED-BEACH_722928_CZ2025.BINM
# +--- CA_CAMP-PENDLETON-RED-BEACH_722928_CZ2025.epw
# +--- CA_CAMP-PENDLETON-RED-BEACH_722928_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CAMPO_747186_CZ2025.zip
# +--- CA_CAMPO_747186_CZ2025.BINM
# +--- CA_CAMPO_747186_CZ2025.epw
# +--- CA_CAMPO_747186_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CARLSBAD-MCCLELLAN-AP_722927_CZ2025.zip
# +--- CA_CARLSBAD-MCCLELLAN-AP_722927_CZ2025.BINM
# +--- CA_CARLSBAD-MCCLELLAN-AP_722927_CZ2025.epw
# +--- CA_CARLSBAD-MCCLELLAN-AP_722927_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CHICO-MUNI-AP_724973_CZ2025.zip
# +--- CA_CHICO-MUNI-AP_724973_CZ2025.BINM
# +--- CA_CHICO-MUNI-AP_724973_CZ2025.epw
# +--- CA_CHICO-MUNI-AP_724973_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CHINA-LAKE-NAF_746120_CZ2025.zip
# +--- CA_CHINA-LAKE-NAF_746120_CZ2025.BINM
# +--- CA_CHINA-LAKE-NAF_746120_CZ2025.epw
# +--- CA_CHINA-LAKE-NAF_746120_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CHINO-AP_722899_CZ2025.zip
# +--- CA_CHINO-AP_722899_CZ2025.BINM
# +--- CA_CHINO-AP_722899_CZ2025.epw
# +--- CA_CHINO-AP_722899_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_COLUMBIA_720615_CZ2025.zip
# +--- CA_COLUMBIA_720615_CZ2025.BINM
# +--- CA_COLUMBIA_720615_CZ2025.epw
# +--- CA_COLUMBIA_720615_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CONCORD-BUCHANAN-FIELD_724950_CZ2025.zip
# +--- CA_CONCORD-BUCHANAN-FIELD_724950_CZ2025.BINM
# +--- CA_CONCORD-BUCHANAN-FIELD_724950_CZ2025.epw
# +--- CA_CONCORD-BUCHANAN-FIELD_724950_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CORONA-MUNI-AP_720333_CZ2025.zip
# +--- CA_CORONA-MUNI-AP_720333_CZ2025.BINM
# +--- CA_CORONA-MUNI-AP_720333_CZ2025.epw
# +--- CA_CORONA-MUNI-AP_720333_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_CRESCENT-CITY-FAA-AP_725946_CZ2025.zip
# +--- CA_CRESCENT-CITY-FAA-AP_725946_CZ2025.BINM
# +--- CA_CRESCENT-CITY-FAA-AP_725946_CZ2025.epw
# +--- CA_CRESCENT-CITY-FAA-AP_725946_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_DAGGETT-BARSTOW-DAGGETT-AP_723815_CZ2025.zip
# +--- CA_DAGGETT-BARSTOW-DAGGETT-AP_723815_CZ2025.BINM
# +--- CA_DAGGETT-BARSTOW-DAGGETT-AP_723815_CZ2025.epw
# +--- CA_DAGGETT-BARSTOW-DAGGETT-AP_723815_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_DAVIS-UNIV-AP_720576_CZ2025.zip
# +--- CA_DAVIS-UNIV-AP_720576_CZ2025.BINM
# +--- CA_DAVIS-UNIV-AP_720576_CZ2025.epw
# +--- CA_DAVIS-UNIV-AP_720576_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_EDWARDS-AFB_723810_CZ2025.zip
# +--- CA_EDWARDS-AFB_723810_CZ2025.BINM
# +--- CA_EDWARDS-AFB_723810_CZ2025.epw
# +--- CA_EDWARDS-AFB_723810_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_EDWARDS-N-BASE_723171_CZ2025.zip
# +--- CA_EDWARDS-N-BASE_723171_CZ2025.BINM
# +--- CA_EDWARDS-N-BASE_723171_CZ2025.epw
# +--- CA_EDWARDS-N-BASE_723171_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_EL-CENTRO-NAF_722810_CZ2025.zip
# +--- CA_EL-CENTRO-NAF_722810_CZ2025.BINM
# +--- CA_EL-CENTRO-NAF_722810_CZ2025.epw
# +--- CA_EL-CENTRO-NAF_722810_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_EL-MONTE_747043_CZ2025.zip
# +--- CA_EL-MONTE_747043_CZ2025.BINM
# +--- CA_EL-MONTE_747043_CZ2025.epw
# +--- CA_EL-MONTE_747043_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_EUREKA_725940_CZ2025.zip
# +--- CA_EUREKA_725940_CZ2025.BINM
# +--- CA_EUREKA_725940_CZ2025.epw
# +--- CA_EUREKA_725940_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_FAIRFIELD-TRAVIS-AFB_745160_CZ2025.zip
# +--- CA_FAIRFIELD-TRAVIS-AFB_745160_CZ2025.BINM
# +--- CA_FAIRFIELD-TRAVIS-AFB_745160_CZ2025.epw
# +--- CA_FAIRFIELD-TRAVIS-AFB_745160_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_FRESNO-CHANDLER-EXEC-AP_723897_CZ2025.zip
# +--- CA_FRESNO-CHANDLER-EXEC-AP_723897_CZ2025.BINM
# +--- CA_FRESNO-CHANDLER-EXEC-AP_723897_CZ2025.epw
# +--- CA_FRESNO-CHANDLER-EXEC-AP_723897_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.zip
# +--- CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.BINM
# +--- CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.epw
# +--- CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_FULLERTON-MUNI-AP_722976_CZ2025.zip
# +--- CA_FULLERTON-MUNI-AP_722976_CZ2025.BINM
# +--- CA_FULLERTON-MUNI-AP_722976_CZ2025.epw
# +--- CA_FULLERTON-MUNI-AP_722976_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_GEORGE-AFB_723825_CZ2025.zip
# +--- CA_GEORGE-AFB_723825_CZ2025.BINM
# +--- CA_GEORGE-AFB_723825_CZ2025.epw
# +--- CA_GEORGE-AFB_723825_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_GNOSS-FIELD_720406_CZ2025.zip
# +--- CA_GNOSS-FIELD_720406_CZ2025.BINM
# +--- CA_GNOSS-FIELD_720406_CZ2025.epw
# +--- CA_GNOSS-FIELD_720406_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_GRAY-BUTTE-FLD_720952_CZ2025.zip
# +--- CA_GRAY-BUTTE-FLD_720952_CZ2025.BINM
# +--- CA_GRAY-BUTTE-FLD_720952_CZ2025.epw
# +--- CA_GRAY-BUTTE-FLD_720952_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_HALF-MOON-BAY-AP_720646_CZ2025.zip
# +--- CA_HALF-MOON-BAY-AP_720646_CZ2025.BINM
# +--- CA_HALF-MOON-BAY-AP_720646_CZ2025.epw
# +--- CA_HALF-MOON-BAY-AP_720646_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_HANFORD-MUNI-AP_723898_CZ2025.zip
# +--- CA_HANFORD-MUNI-AP_723898_CZ2025.BINM
# +--- CA_HANFORD-MUNI-AP_723898_CZ2025.epw
# +--- CA_HANFORD-MUNI-AP_723898_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_HAYWARD-EXEC-AP_725850_CZ2025.zip
# +--- CA_HAYWARD-EXEC-AP_725850_CZ2025.BINM
# +--- CA_HAYWARD-EXEC-AP_725850_CZ2025.epw
# +--- CA_HAYWARD-EXEC-AP_725850_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_HOLLISTER-MUNI_749179_CZ2025.zip
# +--- CA_HOLLISTER-MUNI_749179_CZ2025.BINM
# +--- CA_HOLLISTER-MUNI_749179_CZ2025.epw
# +--- CA_HOLLISTER-MUNI_749179_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_IMPERIAL-BEACH-REAM-FLD_722909_CZ2025.zip
# +--- CA_IMPERIAL-BEACH-REAM-FLD_722909_CZ2025.BINM
# +--- CA_IMPERIAL-BEACH-REAM-FLD_722909_CZ2025.epw
# +--- CA_IMPERIAL-BEACH-REAM-FLD_722909_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_IMPERIAL_747185_CZ2025.zip
# +--- CA_IMPERIAL_747185_CZ2025.BINM
# +--- CA_IMPERIAL_747185_CZ2025.epw
# +--- CA_IMPERIAL_747185_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_JACK-NORTHROP-FLD-H_722956_CZ2025.zip
# +--- CA_JACK-NORTHROP-FLD-H_722956_CZ2025.BINM
# +--- CA_JACK-NORTHROP-FLD-H_722956_CZ2025.epw
# +--- CA_JACK-NORTHROP-FLD-H_722956_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LA-VERNE-BRACKETT_722887_CZ2025.zip
# +--- CA_LA-VERNE-BRACKETT_722887_CZ2025.BINM
# +--- CA_LA-VERNE-BRACKETT_722887_CZ2025.epw
# +--- CA_LA-VERNE-BRACKETT_722887_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LAKE-TAHOE_725847_CZ2025.zip
# +--- CA_LAKE-TAHOE_725847_CZ2025.BINM
# +--- CA_LAKE-TAHOE_725847_CZ2025.epw
# +--- CA_LAKE-TAHOE_725847_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LANCASTER-GEN-WM-FOX-FIELD_723816_CZ2025.zip
# +--- CA_LANCASTER-GEN-WM-FOX-FIELD_723816_CZ2025.BINM
# +--- CA_LANCASTER-GEN-WM-FOX-FIELD_723816_CZ2025.epw
# +--- CA_LANCASTER-GEN-WM-FOX-FIELD_723816_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LEMOORE-REEVES-NAS_747020_CZ2025.zip
# +--- CA_LEMOORE-REEVES-NAS_747020_CZ2025.BINM
# +--- CA_LEMOORE-REEVES-NAS_747020_CZ2025.epw
# +--- CA_LEMOORE-REEVES-NAS_747020_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LINCOLN-RGNL-AP_720614_CZ2025.zip
# +--- CA_LINCOLN-RGNL-AP_720614_CZ2025.BINM
# +--- CA_LINCOLN-RGNL-AP_720614_CZ2025.epw
# +--- CA_LINCOLN-RGNL-AP_720614_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LIVERMORE-MUNI-AP_724927_CZ2025.zip
# +--- CA_LIVERMORE-MUNI-AP_724927_CZ2025.BINM
# +--- CA_LIVERMORE-MUNI-AP_724927_CZ2025.epw
# +--- CA_LIVERMORE-MUNI-AP_724927_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LOMPOC(AWOS)_722895_CZ2025.zip
# +--- CA_LOMPOC(AWOS)_722895_CZ2025.BINM
# +--- CA_LOMPOC(AWOS)_722895_CZ2025.epw
# +--- CA_LOMPOC(AWOS)_722895_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LONG-BEACH-DAUGHERTY-FLD_722970_CZ2025.zip
# +--- CA_LONG-BEACH-DAUGHERTY-FLD_722970_CZ2025.BINM
# +--- CA_LONG-BEACH-DAUGHERTY-FLD_722970_CZ2025.epw
# +--- CA_LONG-BEACH-DAUGHERTY-FLD_722970_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LOS-ALAMITOS-AAF_722975_CZ2025.zip
# +--- CA_LOS-ALAMITOS-AAF_722975_CZ2025.BINM
# +--- CA_LOS-ALAMITOS-AAF_722975_CZ2025.epw
# +--- CA_LOS-ALAMITOS-AAF_722975_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LOS-ANGELES-DOWNTOWN-USC_722874_CZ2025.zip
# +--- CA_LOS-ANGELES-DOWNTOWN-USC_722874_CZ2025.BINM
# +--- CA_LOS-ANGELES-DOWNTOWN-USC_722874_CZ2025.epw
# +--- CA_LOS-ANGELES-DOWNTOWN-USC_722874_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_LOS-ANGELES-IAP_722950_CZ2025.zip
# +--- CA_LOS-ANGELES-IAP_722950_CZ2025.BINM
# +--- CA_LOS-ANGELES-IAP_722950_CZ2025.epw
# +--- CA_LOS-ANGELES-IAP_722950_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MADERA-MUNI_745046_CZ2025.zip
# +--- CA_MADERA-MUNI_745046_CZ2025.BINM
# +--- CA_MADERA-MUNI_745046_CZ2025.epw
# +--- CA_MADERA-MUNI_745046_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MAMMOTH-YOSEMITE-AP_723894_CZ2025.zip
# +--- CA_MAMMOTH-YOSEMITE-AP_723894_CZ2025.BINM
# +--- CA_MAMMOTH-YOSEMITE-AP_723894_CZ2025.epw
# +--- CA_MAMMOTH-YOSEMITE-AP_723894_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MCCLELLAN-AFB_724836_CZ2025.zip
# +--- CA_MCCLELLAN-AFB_724836_CZ2025.BINM
# +--- CA_MCCLELLAN-AFB_724836_CZ2025.epw
# +--- CA_MCCLELLAN-AFB_724836_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MERCED-CASTLE-AFB_724810_CZ2025.zip
# +--- CA_MERCED-CASTLE-AFB_724810_CZ2025.BINM
# +--- CA_MERCED-CASTLE-AFB_724810_CZ2025.epw
# +--- CA_MERCED-CASTLE-AFB_724810_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MERCED-MUNI-MACREADY-FIELD_724815_CZ2025.zip
# +--- CA_MERCED-MUNI-MACREADY-FIELD_724815_CZ2025.BINM
# +--- CA_MERCED-MUNI-MACREADY-FIELD_724815_CZ2025.epw
# +--- CA_MERCED-MUNI-MACREADY-FIELD_724815_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MIRAMAR-MCAS_722931_CZ2025.zip
# +--- CA_MIRAMAR-MCAS_722931_CZ2025.BINM
# +--- CA_MIRAMAR-MCAS_722931_CZ2025.epw
# +--- CA_MIRAMAR-MCAS_722931_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MODESTO-CITY-CO-AP_724926_CZ2025.zip
# +--- CA_MODESTO-CITY-CO-AP_724926_CZ2025.BINM
# +--- CA_MODESTO-CITY-CO-AP_724926_CZ2025.epw
# +--- CA_MODESTO-CITY-CO-AP_724926_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MOJAVE_722953_CZ2025.zip
# +--- CA_MOJAVE_722953_CZ2025.BINM
# +--- CA_MOJAVE_722953_CZ2025.epw
# +--- CA_MOJAVE_722953_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MONTAGUE-SISKIYOU-CO-AP_725955_CZ2025.zip
# +--- CA_MONTAGUE-SISKIYOU-CO-AP_725955_CZ2025.BINM
# +--- CA_MONTAGUE-SISKIYOU-CO-AP_725955_CZ2025.epw
# +--- CA_MONTAGUE-SISKIYOU-CO-AP_725955_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MONTEREY-PENINSULA_724915_CZ2025.zip
# +--- CA_MONTEREY-PENINSULA_724915_CZ2025.BINM
# +--- CA_MONTEREY-PENINSULA_724915_CZ2025.epw
# +--- CA_MONTEREY-PENINSULA_724915_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MOUNT-SHASTA_725957_CZ2025.zip
# +--- CA_MOUNT-SHASTA_725957_CZ2025.BINM
# +--- CA_MOUNT-SHASTA_725957_CZ2025.epw
# +--- CA_MOUNT-SHASTA_725957_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MOUNT-WILSON_722890_CZ2025.zip
# +--- CA_MOUNT-WILSON_722890_CZ2025.BINM
# +--- CA_MOUNT-WILSON_722890_CZ2025.epw
# +--- CA_MOUNT-WILSON_722890_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_MOUNTAIN-VIEW-MOFFETT-FLD_745090_CZ2025.zip
# +--- CA_MOUNTAIN-VIEW-MOFFETT-FLD_745090_CZ2025.BINM
# +--- CA_MOUNTAIN-VIEW-MOFFETT-FLD_745090_CZ2025.epw
# +--- CA_MOUNTAIN-VIEW-MOFFETT-FLD_745090_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_NAPA-CO_724955_CZ2025.zip
# +--- CA_NAPA-CO_724955_CZ2025.BINM
# +--- CA_NAPA-CO_724955_CZ2025.epw
# +--- CA_NAPA-CO_724955_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_NEEDLES-AP_723805_CZ2025.zip
# +--- CA_NEEDLES-AP_723805_CZ2025.BINM
# +--- CA_NEEDLES-AP_723805_CZ2025.epw
# +--- CA_NEEDLES-AP_723805_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_NEVADA-CO-AIR-PARK_749486_CZ2025.zip
# +--- CA_NEVADA-CO-AIR-PARK_749486_CZ2025.BINM
# +--- CA_NEVADA-CO-AIR-PARK_749486_CZ2025.epw
# +--- CA_NEVADA-CO-AIR-PARK_749486_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_OAKLAND-METRO-AP_724930_CZ2025.zip
# +--- CA_OAKLAND-METRO-AP_724930_CZ2025.BINM
# +--- CA_OAKLAND-METRO-AP_724930_CZ2025.epw
# +--- CA_OAKLAND-METRO-AP_724930_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_OCEANSIDE-MUNI-AP_722934_CZ2025.zip
# +--- CA_OCEANSIDE-MUNI-AP_722934_CZ2025.BINM
# +--- CA_OCEANSIDE-MUNI-AP_722934_CZ2025.epw
# +--- CA_OCEANSIDE-MUNI-AP_722934_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_ONTARIO-IAP_747040_CZ2025.zip
# +--- CA_ONTARIO-IAP_747040_CZ2025.BINM
# +--- CA_ONTARIO-IAP_747040_CZ2025.epw
# +--- CA_ONTARIO-IAP_747040_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_OROVILLE_745048_CZ2025.zip
# +--- CA_OROVILLE_745048_CZ2025.BINM
# +--- CA_OROVILLE_745048_CZ2025.epw
# +--- CA_OROVILLE_745048_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_OXNARD-AP_723927_CZ2025.zip
# +--- CA_OXNARD-AP_723927_CZ2025.BINM
# +--- CA_OXNARD-AP_723927_CZ2025.epw
# +--- CA_OXNARD-AP_723927_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PALM-SPRINGS-IAP_722868_CZ2025.zip
# +--- CA_PALM-SPRINGS-IAP_722868_CZ2025.BINM
# +--- CA_PALM-SPRINGS-IAP_722868_CZ2025.epw
# +--- CA_PALM-SPRINGS-IAP_722868_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PALM-SPRINGS-THERMAL-AP_747187_CZ2025.zip
# +--- CA_PALM-SPRINGS-THERMAL-AP_747187_CZ2025.BINM
# +--- CA_PALM-SPRINGS-THERMAL-AP_747187_CZ2025.epw
# +--- CA_PALM-SPRINGS-THERMAL-AP_747187_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PALMDALE-AP_723820_CZ2025.zip
# +--- CA_PALMDALE-AP_723820_CZ2025.BINM
# +--- CA_PALMDALE-AP_723820_CZ2025.epw
# +--- CA_PALMDALE-AP_723820_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PALO-ALTO-AP_724937_CZ2025.zip
# +--- CA_PALO-ALTO-AP_724937_CZ2025.BINM
# +--- CA_PALO-ALTO-AP_724937_CZ2025.epw
# +--- CA_PALO-ALTO-AP_724937_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.zip
# +--- CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.BINM
# +--- CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.epw
# +--- CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PETALUMA-MUNI-AP_720935_CZ2025.zip
# +--- CA_PETALUMA-MUNI-AP_720935_CZ2025.BINM
# +--- CA_PETALUMA-MUNI-AP_720935_CZ2025.epw
# +--- CA_PETALUMA-MUNI-AP_720935_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PLACERVILLE-AP_720645_CZ2025.zip
# +--- CA_PLACERVILLE-AP_720645_CZ2025.BINM
# +--- CA_PLACERVILLE-AP_720645_CZ2025.epw
# +--- CA_PLACERVILLE-AP_720645_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_POINT-MUGU-NF_723910_CZ2025.zip
# +--- CA_POINT-MUGU-NF_723910_CZ2025.BINM
# +--- CA_POINT-MUGU-NF_723910_CZ2025.epw
# +--- CA_POINT-MUGU-NF_723910_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_PORTERVILLE(AWOS)_723895_CZ2025.zip
# +--- CA_PORTERVILLE(AWOS)_723895_CZ2025.BINM
# +--- CA_PORTERVILLE(AWOS)_723895_CZ2025.epw
# +--- CA_PORTERVILLE(AWOS)_723895_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_RAMONA_745056_CZ2025.zip
# +--- CA_RAMONA_745056_CZ2025.BINM
# +--- CA_RAMONA_745056_CZ2025.epw
# +--- CA_RAMONA_745056_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_RED-BLUFF-MUNI-AP_725910_CZ2025.zip
# +--- CA_RED-BLUFF-MUNI-AP_725910_CZ2025.BINM
# +--- CA_RED-BLUFF-MUNI-AP_725910_CZ2025.epw
# +--- CA_RED-BLUFF-MUNI-AP_725910_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_REDDING-MUNI-AP_725920_CZ2025.zip
# +--- CA_REDDING-MUNI-AP_725920_CZ2025.BINM
# +--- CA_REDDING-MUNI-AP_725920_CZ2025.epw
# +--- CA_REDDING-MUNI-AP_725920_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_RIVERSIDE-MARCH-AFB_722860_CZ2025.zip
# +--- CA_RIVERSIDE-MARCH-AFB_722860_CZ2025.BINM
# +--- CA_RIVERSIDE-MARCH-AFB_722860_CZ2025.epw
# +--- CA_RIVERSIDE-MARCH-AFB_722860_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_RIVERSIDE-MUNI_722869_CZ2025.zip
# +--- CA_RIVERSIDE-MUNI_722869_CZ2025.BINM
# +--- CA_RIVERSIDE-MUNI_722869_CZ2025.epw
# +--- CA_RIVERSIDE-MUNI_722869_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_ROHNERVILLE_749485_CZ2025.zip
# +--- CA_ROHNERVILLE_749485_CZ2025.BINM
# +--- CA_ROHNERVILLE_749485_CZ2025.epw
# +--- CA_ROHNERVILLE_749485_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.zip
# +--- CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.BINM
# +--- CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.epw
# +--- CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SACRAMENTO-MATHER-FL_724833_CZ2025.zip
# +--- CA_SACRAMENTO-MATHER-FL_724833_CZ2025.BINM
# +--- CA_SACRAMENTO-MATHER-FL_724833_CZ2025.epw
# +--- CA_SACRAMENTO-MATHER-FL_724833_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SACRAMENTO-METRO-AP_724839_CZ2025.zip
# +--- CA_SACRAMENTO-METRO-AP_724839_CZ2025.BINM
# +--- CA_SACRAMENTO-METRO-AP_724839_CZ2025.epw
# +--- CA_SACRAMENTO-METRO-AP_724839_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SALINAS-MUNI-AP_725930_CZ2025.zip
# +--- CA_SALINAS-MUNI-AP_725930_CZ2025.BINM
# +--- CA_SALINAS-MUNI-AP_725930_CZ2025.epw
# +--- CA_SALINAS-MUNI-AP_725930_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-BERNARDINO-IAP_722866_CZ2025.zip
# +--- CA_SAN-BERNARDINO-IAP_722866_CZ2025.BINM
# +--- CA_SAN-BERNARDINO-IAP_722866_CZ2025.epw
# +--- CA_SAN-BERNARDINO-IAP_722866_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-CARLOS-AP_724938_CZ2025.zip
# +--- CA_SAN-CARLOS-AP_724938_CZ2025.BINM
# +--- CA_SAN-CARLOS-AP_724938_CZ2025.epw
# +--- CA_SAN-CARLOS-AP_724938_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-CLEMENTE-IS-NAAS_722925_CZ2025.zip
# +--- CA_SAN-CLEMENTE-IS-NAAS_722925_CZ2025.BINM
# +--- CA_SAN-CLEMENTE-IS-NAAS_722925_CZ2025.epw
# +--- CA_SAN-CLEMENTE-IS-NAAS_722925_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-DIEGO-GILLESPIE_722907_CZ2025.zip
# +--- CA_SAN-DIEGO-GILLESPIE_722907_CZ2025.BINM
# +--- CA_SAN-DIEGO-GILLESPIE_722907_CZ2025.epw
# +--- CA_SAN-DIEGO-GILLESPIE_722907_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.zip
# +--- CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.BINM
# +--- CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.epw
# +--- CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-DIEGO-MONTGOMERY_722903_CZ2025.zip
# +--- CA_SAN-DIEGO-MONTGOMERY_722903_CZ2025.BINM
# +--- CA_SAN-DIEGO-MONTGOMERY_722903_CZ2025.epw
# +--- CA_SAN-DIEGO-MONTGOMERY_722903_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-DIEGO-NORTH-ISLAND-NAS_722906_CZ2025.zip
# +--- CA_SAN-DIEGO-NORTH-ISLAND-NAS_722906_CZ2025.BINM
# +--- CA_SAN-DIEGO-NORTH-ISLAND-NAS_722906_CZ2025.epw
# +--- CA_SAN-DIEGO-NORTH-ISLAND-NAS_722906_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-FRANCISCO-IAP_724940_CZ2025.zip
# +--- CA_SAN-FRANCISCO-IAP_724940_CZ2025.BINM
# +--- CA_SAN-FRANCISCO-IAP_724940_CZ2025.epw
# +--- CA_SAN-FRANCISCO-IAP_724940_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-JOSE-IAP_724945_CZ2025.zip
# +--- CA_SAN-JOSE-IAP_724945_CZ2025.BINM
# +--- CA_SAN-JOSE-IAP_724945_CZ2025.epw
# +--- CA_SAN-JOSE-IAP_724945_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-JOSE-REID-HILLV_724946_CZ2025.zip
# +--- CA_SAN-JOSE-REID-HILLV_724946_CZ2025.BINM
# +--- CA_SAN-JOSE-REID-HILLV_724946_CZ2025.epw
# +--- CA_SAN-JOSE-REID-HILLV_724946_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SAN-LUIS-CO-RGNL-AP_722897_CZ2025.zip
# +--- CA_SAN-LUIS-CO-RGNL-AP_722897_CZ2025.BINM
# +--- CA_SAN-LUIS-CO-RGNL-AP_722897_CZ2025.epw
# +--- CA_SAN-LUIS-CO-RGNL-AP_722897_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANDBERG_723830_CZ2025.zip
# +--- CA_SANDBERG_723830_CZ2025.BINM
# +--- CA_SANDBERG_723830_CZ2025.epw
# +--- CA_SANDBERG_723830_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANTA-ANA-JOHN-WAYNE-AP_722977_CZ2025.zip
# +--- CA_SANTA-ANA-JOHN-WAYNE-AP_722977_CZ2025.BINM
# +--- CA_SANTA-ANA-JOHN-WAYNE-AP_722977_CZ2025.epw
# +--- CA_SANTA-ANA-JOHN-WAYNE-AP_722977_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANTA-BARBARA-MUNI-AP_723925_CZ2025.zip
# +--- CA_SANTA-BARBARA-MUNI-AP_723925_CZ2025.BINM
# +--- CA_SANTA-BARBARA-MUNI-AP_723925_CZ2025.epw
# +--- CA_SANTA-BARBARA-MUNI-AP_723925_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANTA-CATALINA-CATALINA-AP_722920_CZ2025.zip
# +--- CA_SANTA-CATALINA-CATALINA-AP_722920_CZ2025.BINM
# +--- CA_SANTA-CATALINA-CATALINA-AP_722920_CZ2025.epw
# +--- CA_SANTA-CATALINA-CATALINA-AP_722920_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.zip
# +--- CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.BINM
# +--- CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.epw
# +--- CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANTA-MONICA-MUNI_722885_CZ2025.zip
# +--- CA_SANTA-MONICA-MUNI_722885_CZ2025.BINM
# +--- CA_SANTA-MONICA-MUNI_722885_CZ2025.epw
# +--- CA_SANTA-MONICA-MUNI_722885_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANTA-ROSA(AWOS)_724957_CZ2025.zip
# +--- CA_SANTA-ROSA(AWOS)_724957_CZ2025.BINM
# +--- CA_SANTA-ROSA(AWOS)_724957_CZ2025.epw
# +--- CA_SANTA-ROSA(AWOS)_724957_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SANTA-YNEZ_723762_CZ2025.zip
# +--- CA_SANTA-YNEZ_723762_CZ2025.BINM
# +--- CA_SANTA-YNEZ_723762_CZ2025.epw
# +--- CA_SANTA-YNEZ_723762_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SOUTH-CO-AP-OF-SANTA-CLARA_749484_CZ2025.zip
# +--- CA_SOUTH-CO-AP-OF-SANTA-CLARA_749484_CZ2025.BINM
# +--- CA_SOUTH-CO-AP-OF-SANTA-CLARA_749484_CZ2025.epw
# +--- CA_SOUTH-CO-AP-OF-SANTA-CLARA_749484_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_STOCKTON-METRO-AP_724920_CZ2025.zip
# +--- CA_STOCKTON-METRO-AP_724920_CZ2025.BINM
# +--- CA_STOCKTON-METRO-AP_724920_CZ2025.epw
# +--- CA_STOCKTON-METRO-AP_724920_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_SUSANVILLE-MUNI_725837_CZ2025.zip
# +--- CA_SUSANVILLE-MUNI_725837_CZ2025.BINM
# +--- CA_SUSANVILLE-MUNI_725837_CZ2025.epw
# +--- CA_SUSANVILLE-MUNI_725837_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_TEHACHAPI-MUNI_749171_CZ2025.zip
# +--- CA_TEHACHAPI-MUNI_749171_CZ2025.BINM
# +--- CA_TEHACHAPI-MUNI_749171_CZ2025.epw
# +--- CA_TEHACHAPI-MUNI_749171_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_TORRANCE-MUNI-AP_722955_CZ2025.zip
# +--- CA_TORRANCE-MUNI-AP_722955_CZ2025.BINM
# +--- CA_TORRANCE-MUNI-AP_722955_CZ2025.epw
# +--- CA_TORRANCE-MUNI-AP_722955_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_TRUCKEE-TAHOE_725846_CZ2025.zip
# +--- CA_TRUCKEE-TAHOE_725846_CZ2025.BINM
# +--- CA_TRUCKEE-TAHOE_725846_CZ2025.epw
# +--- CA_TRUCKEE-TAHOE_725846_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_TWENTYNINE-PALMS_690150_CZ2025.zip
# +--- CA_TWENTYNINE-PALMS_690150_CZ2025.BINM
# +--- CA_TWENTYNINE-PALMS_690150_CZ2025.epw
# +--- CA_TWENTYNINE-PALMS_690150_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_UKIAH-MUNI-AP_725905_CZ2025.zip
# +--- CA_UKIAH-MUNI-AP_725905_CZ2025.BINM
# +--- CA_UKIAH-MUNI-AP_725905_CZ2025.epw
# +--- CA_UKIAH-MUNI-AP_725905_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_USMC-MTN-WARFARE-TRAIN-CTR_720652_CZ2025.zip
# +--- CA_USMC-MTN-WARFARE-TRAIN-CTR_720652_CZ2025.BINM
# +--- CA_USMC-MTN-WARFARE-TRAIN-CTR_720652_CZ2025.epw
# +--- CA_USMC-MTN-WARFARE-TRAIN-CTR_720652_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_VACAVILLE-NUT-TREE_724828_CZ2025.zip
# +--- CA_VACAVILLE-NUT-TREE_724828_CZ2025.BINM
# +--- CA_VACAVILLE-NUT-TREE_724828_CZ2025.epw
# +--- CA_VACAVILLE-NUT-TREE_724828_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_VAN-NUYS-AP_722886_CZ2025.zip
# +--- CA_VAN-NUYS-AP_722886_CZ2025.BINM
# +--- CA_VAN-NUYS-AP_722886_CZ2025.epw
# +--- CA_VAN-NUYS-AP_722886_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_VANDENBERG-AFB_723930_CZ2025.zip
# +--- CA_VANDENBERG-AFB_723930_CZ2025.BINM
# +--- CA_VANDENBERG-AFB_723930_CZ2025.epw
# +--- CA_VANDENBERG-AFB_723930_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_VISALIA-MUNI(AWOS)_723896_CZ2025.zip
# +--- CA_VISALIA-MUNI(AWOS)_723896_CZ2025.BINM
# +--- CA_VISALIA-MUNI(AWOS)_723896_CZ2025.epw
# +--- CA_VISALIA-MUNI(AWOS)_723896_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_WATSONVILLE_745058_CZ2025.zip
# +--- CA_WATSONVILLE_745058_CZ2025.BINM
# +--- CA_WATSONVILLE_745058_CZ2025.epw
# +--- CA_WATSONVILLE_745058_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_WEAVERVILLE-LONNIE-POOL-FIELD_720193_CZ2025.zip
# +--- CA_WEAVERVILLE-LONNIE-POOL-FIELD_720193_CZ2025.BINM
# +--- CA_WEAVERVILLE-LONNIE-POOL-FIELD_720193_CZ2025.epw
# +--- CA_WEAVERVILLE-LONNIE-POOL-FIELD_720193_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_WHITEMAN-AP_745057_CZ2025.zip
# +--- CA_WHITEMAN-AP_745057_CZ2025.BINM
# +--- CA_WHITEMAN-AP_745057_CZ2025.epw
# +--- CA_WHITEMAN-AP_745057_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
# CA_YUBA-CO_724838_CZ2025.zip
# +--- CA_YUBA-CO_724838_CZ2025.BINM
# +--- CA_YUBA-CO_724838_CZ2025.epw
# +--- CA_YUBA-CO_724838_CZ2025.FIN4
# +--- Terms of Use.pdf
# +--- Importing FIN4 files into Excel.txt
#
# Searching for CA_ARCATA-AP_725945
# ('CA_ARCATA-AP_725945_CZ2025.zip', 'CA_ARCATA-AP_725945_CZ2025.epw')
# CZ2025\CZ01-CA_ARCATA-AP_725945_CZ2025.epw
# Searching for CA_SANTA-ROSA(AWOS)_724957
# ('CA_SANTA-ROSA(AWOS)_724957_CZ2025.zip', 'CA_SANTA-ROSA(AWOS)_724957_CZ2025.epw')
# CZ2025\CZ02-CA_SANTA-ROSA(AWOS)_724957_CZ2025.epw
# Searching for CA_OAKLAND-METRO-AP_724930
# ('CA_OAKLAND-METRO-AP_724930_CZ2025.zip', 'CA_OAKLAND-METRO-AP_724930_CZ2025.epw')
# CZ2025\CZ03-CA_OAKLAND-METRO-AP_724930_CZ2025.epw
# Searching for CA_PASO-ROBLES-MUNI-AP_723965
# ('CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.zip', 'CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.epw')
# CZ2025\CZ04-CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.epw
# Searching for CA_SANTA-MARIA-PUBLIC-AP_723940
# ('CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.zip', 'CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.epw')
# CZ2025\CZ05-CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.epw
# Searching for CA_LOS-ANGELES-IAP_722950
# ('CA_LOS-ANGELES-IAP_722950_CZ2025.zip', 'CA_LOS-ANGELES-IAP_722950_CZ2025.epw')
# CZ2025\CZ06-CA_LOS-ANGELES-IAP_722950_CZ2025.epw
# Searching for CA_SAN-DIEGO-LINDBERGH-FIELD_722900
# ('CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.zip', 'CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.epw')
# CZ2025\CZ07-CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.epw
# Searching for CA_FULLERTON-MUNI-AP_722976
# ('CA_FULLERTON-MUNI-AP_722976_CZ2025.zip', 'CA_FULLERTON-MUNI-AP_722976_CZ2025.epw')
# CZ2025\CZ08-CA_FULLERTON-MUNI-AP_722976_CZ2025.epw
# Searching for CA_BURBANK-GLNDLE-PASAD-AP_722880
# ('CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.zip', 'CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.epw')
# CZ2025\CZ09-CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.epw
# Searching for CA_RIVERSIDE-MUNI_722869
# ('CA_RIVERSIDE-MUNI_722869_CZ2025.zip', 'CA_RIVERSIDE-MUNI_722869_CZ2025.epw')
# CZ2025\CZ10-CA_RIVERSIDE-MUNI_722869_CZ2025.epw
# Searching for CA_RED-BLUFF-MUNI-AP_725910
# ('CA_RED-BLUFF-MUNI-AP_725910_CZ2025.zip', 'CA_RED-BLUFF-MUNI-AP_725910_CZ2025.epw')
# CZ2025\CZ11-CA_RED-BLUFF-MUNI-AP_725910_CZ2025.epw
# Searching for CA_SACRAMENTO-EXECUTIVE-AP_724830
# ('CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.zip', 'CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.epw')
# CZ2025\CZ12-CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.epw
# Searching for CA_FRESNO-YOSEMITE-IAP_723890
# ('CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.zip', 'CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.epw')
# CZ2025\CZ13-CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.epw
# Searching for CA_PALMDALE-AP_723820
# ('CA_PALMDALE-AP_723820_CZ2025.zip', 'CA_PALMDALE-AP_723820_CZ2025.epw')
# CZ2025\CZ14-CA_PALMDALE-AP_723820_CZ2025.epw
# Searching for CA_PALM-SPRINGS-IAP_722868
# ('CA_PALM-SPRINGS-IAP_722868_CZ2025.zip', 'CA_PALM-SPRINGS-IAP_722868_CZ2025.epw')
# CZ2025\CZ15-CA_PALM-SPRINGS-IAP_722868_CZ2025.epw
# Searching for CA_BLUE-CANYON-AP_725845
# ('CA_BLUE-CANYON-AP_725845_CZ2025.zip', 'CA_BLUE-CANYON-AP_725845_CZ2025.epw')
# CZ2025\CZ16-CA_BLUE-CANYON-AP_725845_CZ2025.epw
# Done

# %%
# Define One Building URLs corresponding to relevant CALMAC stations for extracting ddy files
URLS = [
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ01_Arcata-Eureka-California.Redwood.Coast-Humboldt.County.AP.725945_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ02_Santa.Rosa-Schulz-Sonoma.County.AP.724957_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ03_Oakland.Intl.AP.724930_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ04_Paso.Robles.Muni.AP.723965_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ05_Santa.Maria.Public.AP-Hancock.Field.723940_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ06_Los.Angeles.Intl.AP.722950_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ07_San.Diego.Intl.AP-Lindbergh.Field.722900_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ08_Fullerton.Muni.AP.722976_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ09_Hollywood.Burbank.AP.722880_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ10_Riverside.Muni.AP.722869_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ11_Red.Bluff.Muni.AP.725910_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ12_Sacramento.Exec.AP.724830_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ13_Fresno.Yosemite.Intl.AP.723890_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ14_Palmdale.Rgnl.AP.723820_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ15_Palm.Springs.Intl.AP.722868_CTZ2025.zip",
    "https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/California_Climate_Zones/California_CTZ_2025/USA_CA_CZ16_Blue.Canyon-Nyack.AP.725845_CTZ2025.zip",
]

# Define output folder
output_folder = Path("CZ2025")
output_folder.mkdir(parents=True, exist_ok=True)

# %%
# Pattern matching CZ in the ddy filename, and mapping to the corresponding epw filename
CZ_RE = re.compile(r"(CZ\d{2})", re.IGNORECASE)

cz_to_epw = {}

for epw in output_folder.glob("*.epw"):
    m = CZ_RE.search(epw.name)
    if m:
        cz_to_epw[m.group(1).upper()] = epw.name

if not cz_to_epw:
    raise RuntimeError("No .epw files with CZ## found in output_folder")

# %%
# Loop through the One Building URLs, download the ZIP files, extract .ddy files, and save them with the correct names
for url in URLS:
    zip_name = Path(url).name
    zip_path = output_folder / zip_name

    # Download the ZIP file if it doesn't exist
    if not zip_path.exists():
        print("Downloading", url)

        r0 = requests.head(url, allow_redirects=True)
        print(r0.headers)

        r1 = requests.get(url)
        r1.raise_for_status()
        zip_path.write_bytes(r1.content)

    filestats = zip_path.stat()
    print(
        zip_path,
        filestats.st_size,
        datetime.fromtimestamp(filestats.st_mtime).isoformat()
    )

    # Extract .ddy files from the ZIP archive and save them with the correct names
    with ZipFile(zip_path, "r") as z:
        ddy_members = [n for n in z.namelist() if n.lower().endswith(".ddy")]
        if not ddy_members:
            raise RuntimeError(f"No .ddy file in {zip_name}")

        for member in ddy_members:
            member_name = Path(member).name
            m = CZ_RE.search(member_name) or CZ_RE.search(zip_name)
            if not m:
                raise RuntimeError(f"Cannot determine CZ for {member_name}")

            cz = m.group(1).upper()

            if cz not in cz_to_epw:
                raise RuntimeError(f"No matching EPW file for {cz}")

            epw_name = cz_to_epw[cz]
            ddy_name = Path(epw_name).with_suffix(".ddy").name
            ddy_path = output_folder / ddy_name

            with z.open(member) as src, open(ddy_path, "wb") as dst:
                dst.write(src.read())

            print(f"Extracted {member_name} -> {ddy_name}")
# Out:
# CZ2025\USA_CA_CZ01_Arcata-Eureka-California.Redwood.Coast-Humboldt.County.AP.725945_CTZ2025.zip 397482 2026-02-27T13:44:10.587627
# Extracted USA_CA_CZ01_Arcata-Eureka-California.Redwood.Coast-Humboldt.County.AP.725945_CTZ2025.ddy -> CZ01-CA_ARCATA-AP_725945_CZ2025.ddy
# CZ2025\USA_CA_CZ02_Santa.Rosa-Schulz-Sonoma.County.AP.724957_CTZ2025.zip 399366 2026-02-27T13:44:57.975804
# Extracted USA_CA_CZ02_Santa.Rosa-Schulz-Sonoma.County.AP.724957_CTZ2025.ddy -> CZ02-CA_SANTA-ROSA(AWOS)_724957_CZ2025.ddy
# CZ2025\USA_CA_CZ03_Oakland.Intl.AP.724930_CTZ2025.zip 397624 2026-02-27T13:44:59.166113
# Extracted USA_CA_CZ03_Oakland.Intl.AP.724930_CTZ2025.ddy -> CZ03-CA_OAKLAND-METRO-AP_724930_CZ2025.ddy
# CZ2025\USA_CA_CZ04_Paso.Robles.Muni.AP.723965_CTZ2025.zip 408894 2026-02-27T13:45:00.335091
# Extracted USA_CA_CZ04_Paso.Robles.Muni.AP.723965_CTZ2025.ddy -> CZ04-CA_PASO-ROBLES-MUNI-AP_723965_CZ2025.ddy
# CZ2025\USA_CA_CZ05_Santa.Maria.Public.AP-Hancock.Field.723940_CTZ2025.zip 402947 2026-02-27T13:45:01.514046
# Extracted USA_CA_CZ05_Santa.Maria.Public.AP-Hancock.Field.723940_CTZ2025.ddy -> CZ05-CA_SANTA-MARIA-PUBLIC-AP_723940_CZ2025.ddy
# CZ2025\USA_CA_CZ06_Los.Angeles.Intl.AP.722950_CTZ2025.zip 401505 2026-02-27T13:45:02.680511
# Extracted USA_CA_CZ06_Los.Angeles.Intl.AP.722950_CTZ2025.ddy -> CZ06-CA_LOS-ANGELES-IAP_722950_CZ2025.ddy
# CZ2025\USA_CA_CZ07_San.Diego.Intl.AP-Lindbergh.Field.722900_CTZ2025.zip 395419 2026-02-27T13:45:03.861074
# Extracted USA_CA_CZ07_San.Diego.Intl.AP-Lindbergh.Field.722900_CTZ2025.ddy -> CZ07-CA_SAN-DIEGO-LINDBERGH-FIELD_722900_CZ2025.ddy
# CZ2025\USA_CA_CZ08_Fullerton.Muni.AP.722976_CTZ2025.zip 387515 2026-02-27T13:45:05.064054
# Extracted USA_CA_CZ08_Fullerton.Muni.AP.722976_CTZ2025.ddy -> CZ08-CA_FULLERTON-MUNI-AP_722976_CZ2025.ddy
# CZ2025\USA_CA_CZ09_Hollywood.Burbank.AP.722880_CTZ2025.zip 400407 2026-02-27T13:45:06.245346
# Extracted USA_CA_CZ09_Hollywood.Burbank.AP.722880_CTZ2025.ddy -> CZ09-CA_BURBANK-GLNDLE-PASAD-AP_722880_CZ2025.ddy
# CZ2025\USA_CA_CZ10_Riverside.Muni.AP.722869_CTZ2025.zip 399986 2026-02-27T13:45:07.425081
# Extracted USA_CA_CZ10_Riverside.Muni.AP.722869_CTZ2025.ddy -> CZ10-CA_RIVERSIDE-MUNI_722869_CZ2025.ddy
# CZ2025\USA_CA_CZ11_Red.Bluff.Muni.AP.725910_CTZ2025.zip 411001 2026-02-27T13:45:08.642252
# Extracted USA_CA_CZ11_Red.Bluff.Muni.AP.725910_CTZ2025.ddy -> CZ11-CA_RED-BLUFF-MUNI-AP_725910_CZ2025.ddy
# CZ2025\USA_CA_CZ12_Sacramento.Exec.AP.724830_CTZ2025.zip 397911 2026-02-27T13:45:09.852410
# Extracted USA_CA_CZ12_Sacramento.Exec.AP.724830_CTZ2025.ddy -> CZ12-CA_SACRAMENTO-EXECUTIVE-AP_724830_CZ2025.ddy
# CZ2025\USA_CA_CZ13_Fresno.Yosemite.Intl.AP.723890_CTZ2025.zip 407691 2026-02-27T13:45:11.135186
# Extracted USA_CA_CZ13_Fresno.Yosemite.Intl.AP.723890_CTZ2025.ddy -> CZ13-CA_FRESNO-YOSEMITE-IAP_723890_CZ2025.ddy
# CZ2025\USA_CA_CZ14_Palmdale.Rgnl.AP.723820_CTZ2025.zip 410807 2026-02-27T13:45:12.334406
# Extracted USA_CA_CZ14_Palmdale.Rgnl.AP.723820_CTZ2025.ddy -> CZ14-CA_PALMDALE-AP_723820_CZ2025.ddy
# CZ2025\USA_CA_CZ15_Palm.Springs.Intl.AP.722868_CTZ2025.zip 406949 2026-02-27T13:45:13.536964
# Extracted USA_CA_CZ15_Palm.Springs.Intl.AP.722868_CTZ2025.ddy -> CZ15-CA_PALM-SPRINGS-IAP_722868_CZ2025.ddy
# CZ2025\USA_CA_CZ16_Blue.Canyon-Nyack.AP.725845_CTZ2025.zip 397587 2026-02-27T13:45:14.764753
# Extracted USA_CA_CZ16_Blue.Canyon-Nyack.AP.725845_CTZ2025.ddy -> CZ16-CA_BLUE-CANYON-AP_725845_CZ2025.ddy
